# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
Dist=pd.read_csv('district wise rainfall normal.csv')

# %%
Ind = pd.read_csv('rainfall in india 1901-2015.csv')

# %%
Ind['JAN'].fillna((Ind['JAN'].mean()), inplace=True)
Ind['FEB'].fillna((Ind['FEB'].mean()), inplace=True)
Ind['MAR'].fillna((Ind['MAR'].mean()), inplace=True)
Ind['APR'].fillna((Ind['APR'].mean()), inplace=True)
Ind['MAY'].fillna((Ind['MAY'].mean()), inplace=True)
Ind['JUN'].fillna((Ind['JUN'].mean()), inplace=True)
Ind['JUL'].fillna((Ind['JUL'].mean()), inplace=True)
Ind['AUG'].fillna((Ind['AUG'].mean()), inplace=True)
Ind['SEP'].fillna((Ind['SEP'].mean()), inplace=True)
Ind['OCT'].fillna((Ind['OCT'].mean()), inplace=True)
Ind['NOV'].fillna((Ind['NOV'].mean()), inplace=True)
Ind['DEC'].fillna((Ind['DEC'].mean()), inplace=True)
Ind['Jan-Feb'].fillna((Ind['Jan-Feb'].mean()), inplace=True)
Ind['Mar-May'].fillna((Ind['Mar-May'].mean()), inplace=True)
Ind['Jun-Sep'].fillna((Ind['Jun-Sep'].mean()), inplace=True)
Ind['Oct-Dec'].fillna((Ind['Oct-Dec'].mean()), inplace=True)
Ind['ANNUAL'].fillna((Ind['ANNUAL'].mean()), inplace=True)

# %%
S = Dist.sort_values('ANNUAL',ascending=True)
S.head()
# Out:
#          STATE_UT_NAME       DISTRICT   JAN   FEB   MAR   APR   MAY   JUN  \
# 353  JAMMU AND KASHMIR   LADAKH (LEH)   8.1   7.3   8.8   8.0   8.0   3.8
# 374          RAJASTHAN      JAISALMER   1.7   2.9   2.2   3.8   6.6  19.4
# 359  JAMMU AND KASHMIR         KARGIL  25.6  25.6  25.1  19.7  22.0   5.5
# 373          RAJASTHAN  SRI GANGANAGA   6.0   8.0   9.3   7.0  11.6  25.5
# 370          RAJASTHAN         BARMER   1.2   1.7   2.3   3.2   9.1  27.4
#
#       JUL   AUG   SEP   OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# 353  13.1  14.1   8.6   7.2   3.6   4.0    94.6     15.4     24.8     39.6
# 374  59.3  56.9  22.8   3.1   1.5   1.0   181.2      4.6     12.6    158.4
# 359  11.6  24.0   8.6  14.5  20.6  20.5   223.3     51.2     66.8     49.7
# 373  79.3  64.9  31.7   3.1   2.1   4.4   252.9     14.0     27.9    201.4
# 370  88.6  86.7  40.7   4.1   3.2   0.4   268.6      2.9     14.6    243.4
#
#      Oct-Dec
# 353     14.8
# 374      5.6
# 359     55.6
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import numpy as np
img=np.array(Image.open('AP.jpg'))
fig=plt.figure(figsize=(7,7))
plt.imshow(img,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
AP_d=Dist[Dist['STATE_UT_NAME']=='ANDHRA PRADESH']
AP_d.head()
# Out:
#       STATE_UT_NAME       DISTRICT   JAN   FEB   MAR   APR   MAY    JUN  \
# 537  ANDHRA PRADESH  EAST GODAVARI   6.0  10.1  11.3  22.8  75.3  131.9
# 538  ANDHRA PRADESH  WEST GODAVARI   6.1  10.7   8.7  19.0  55.8  135.8
# 539  ANDHRA PRADESH         GUNTUR   5.5   7.7   7.7  15.0  58.4   90.2
# 540  ANDHRA PRADESH        KRISHNA   4.6   6.3   8.7  16.9  46.8  120.9
# 541  ANDHRA PRADESH        NELLORE  15.7  11.6   6.0  15.2  51.4   53.4
#
#        JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 537  206.4  188.4  177.2  199.0   69.8    7.8  1106.0     16.1    109.4
# 538  240.2  227.8  180.1  197.8   66.7   11.7  1160.4     16.8     83.5
# 539  147.3  155.4  150.1  143.9   75.8   14.5   871.5     13.2     81.1
# 540  216.6  194.2  169.7  164.2   66.1   12.1  1027.1     10.9     72.4
# 541   91.2   95.0  112.8  248.2  283.9  107.2  1091.6     27.3     72.6
#
#      Jun-Sep  Oct-Dec
# 537    703.9    276.6
# 538    783.9    276.2
# 539    543.0    234.2
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
a=AP_d.sort_values("ANNUAL")
a.plot.bar('DISTRICT','ANNUAL',figsize=(10,7))
plt.xlabel('District')
plt.ylabel('Annual rainfall in mm')
plt.title('Annual rainfall in different districts of Andhara Pradesh')
plt.savefig('AP.png')
