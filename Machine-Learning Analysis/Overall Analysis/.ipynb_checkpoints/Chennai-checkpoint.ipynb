# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
Dist=pd.read_csv('district wise rainfall normal.csv')

# %%
Ind = pd.read_csv('rainfall in india 1901-2015.csv')

# %%
Ind.isnull().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
Ind['JAN'].fillna((Ind['JAN'].mean()), inplace=True)
Ind['FEB'].fillna((Ind['FEB'].mean()), inplace=True)
Ind['MAR'].fillna((Ind['MAR'].mean()), inplace=True)
Ind['APR'].fillna((Ind['APR'].mean()), inplace=True)
Ind['MAY'].fillna((Ind['MAY'].mean()), inplace=True)
Ind['JUN'].fillna((Ind['JUN'].mean()), inplace=True)
Ind['JUL'].fillna((Ind['JUL'].mean()), inplace=True)
Ind['AUG'].fillna((Ind['AUG'].mean()), inplace=True)
Ind['SEP'].fillna((Ind['SEP'].mean()), inplace=True)
Ind['OCT'].fillna((Ind['OCT'].mean()), inplace=True)
Ind['NOV'].fillna((Ind['NOV'].mean()), inplace=True)
Ind['DEC'].fillna((Ind['DEC'].mean()), inplace=True)
Ind['Jan-Feb'].fillna((Ind['Jan-Feb'].mean()), inplace=True)
Ind['Mar-May'].fillna((Ind['Mar-May'].mean()), inplace=True)
Ind['Jun-Sep'].fillna((Ind['Jun-Sep'].mean()), inplace=True)
Ind['Oct-Dec'].fillna((Ind['Oct-Dec'].mean()), inplace=True)
Ind['ANNUAL'].fillna((Ind['ANNUAL'].mean()), inplace=True)

# %%
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import numpy as np
img=np.array(Image.open('chennai.jpg'))
fig=plt.figure(figsize=(7,7))
plt.imshow(img,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
tamil_d=Dist[Dist['STATE_UT_NAME']=='TAMIL NADU']
tamil_d.head()
# Out:
#     STATE_UT_NAME     DISTRICT   JAN   FEB   MAR    APR    MAY    JUN    JUL  \
# 560    TAMIL NADU      VELLORE   8.1   6.8   9.2   22.3   75.0   65.9  107.3
# 561    TAMIL NADU   COIMBATORE   8.1  12.2  17.2   53.4   79.7   32.9   47.2
# 562    TAMIL NADU   DHARMAPURI   8.0  10.2  15.9   41.7  102.8   53.6   77.9
# 563    TAMIL NADU  KANYAKUMARI  18.4  22.0  42.5  104.3  141.5  186.1  112.5
# 564    TAMIL NADU      CHENNAI  22.1  14.6   3.0   12.0   43.5   64.1  108.6
#
#        AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# 560  129.0  163.9  163.2  127.2   58.3   936.2     14.9    106.5    466.1
# 561   40.6   69.1  151.9  129.6   47.4   689.3     20.3    150.3    189.8
# 562   99.3  162.6  180.5  103.3   46.3   902.1     18.2    160.4    393.4
# 563   76.7  102.1  226.3  208.6   61.5  1302.5     40.4    288.3    477.4
# 564  147.9  118.5  266.5  367.8  155.6  1324.2     36.7     58.5    439.1
#
#      Oct-Dec
# 560    348.7
# 561    328.9
# 562    330.1
# 563    496.4
# 564    789.9

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
a=tamil_d.sort_values("ANNUAL")
a.plot.bar('DISTRICT','ANNUAL',figsize=(10,7))
plt.xlabel('District')
plt.ylabel('Annual rainfall in mm')
plt.title('Annual rainfall in different districts of Tamilnadu')
# Out:
# Text(0.5,1,'Annual rainfall in different districts of Tamilnadu')
